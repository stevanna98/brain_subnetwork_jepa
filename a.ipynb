# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Kernel keep-alive started. Stop the cell to end.
# [14:05:55] busy 0
# [14:06:55] busy 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_10428/1592790367.py in <cell line: 0>()
#      10     print(f"[{datetime.now().strftime('%H:%M:%S')}] busy {i}", flush=True)
#      11     i += 1
# ---> 12     time.sleep(60)
#
# KeyboardInterrupt:

# %%
import time
from datetime import datetime
 
print("Kernel keep-alive started. Stop the cell to end.")
i = 0
while True:
    print(f"[{datetime.now().strftime('%H:%M:%S')}] busy {i}", flush=True)
    i += 1
    time.sleep(60)
